-- %%
%python
data= [(1,'naval'),(2,'raj')]
schema="id int, name string"

-- %%
%python
df=spark.createDataFrame(data,schema)

-- %% [markdown]
-- Creating a spark dataframe

-- %%
df=spark.createDataFrame(data,schema)

-- %%
display(df)
